# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Read the CSV

# %%
df_lappy = pd.read_csv('lappy_flipkart.csv')
df_lappy.head()
# Out:
#                                                 name  ratings  \
# 0  Lenovo Ideapad S145 Core i5 10th Gen - (8 GB/1...      4.0
# 1  Lenovo Ideapad S145 Core i3 10th Gen - (4 GB/1...      4.3
# 2  Acer Aspire 7 Core i5 9th Gen - (8 GB/512 GB S...      4.5
# 3  Apple MacBook Air Core i5 5th Gen - (8 GB/128 ...      4.7
# 4  Lenovo Ideapad L340 Core i5 9th Gen - (8 GB/1 ...      4.8
#
#                       num_ratings                           processor  \
# 0        431 Ratings & 62 Reviews  Intel Core i5 Processor (10th Gen)
# 1          20 Ratings & 4 Reviews  Intel Core i3 Processor (10th Gen)
# 2     5,317 Ratings & 979 Reviews   Intel Core i5 Processor (9th Gen)
# 3  25,629 Ratings & 2,870 Reviews   Intel Core i5 Processor (5th Gen)
# 4          56 Ratings & 6 Reviews   Intel Core i5 Processor (9th Gen)
#
#              ram                                  os              storage  \
# 0  8 GB DDR4 RAM  64 bit Windows 10 Operating System             1 TB HDD
# 1  4 GB DDR4 RAM  64 bit Windows 10 Operating System             1 TB HDD
# 2  8 GB DDR4 RAM  64 bit Windows 10 Operating System           512 GB SSD
# 3  8 GB DDR3 RAM      64 bit Mac OS Operating System           128 GB SSD
# 4  8 GB DDR4 RAM  64 bit Windows 10 Operating System  1 TB HDD|256 GB SSD
#
#                         display    price org_price
# 0  39.62 cm (15.6 inch) Display  ₹42,990   ₹66,190
# 1  39.62 cm (15.6 inch) Display  ₹31,990   ₹42,490
# 2  39.62 cm (15.6 inch) Display  ₹49,990   ₹79,999
# 3  33.78 cm (13.3 inch) Display  ₹59,990   ₹84,900
# 4  39.62 cm (15.6 inch) Display  ₹55,990   ₹79,690

# %% [markdown]
# ### Separate the Brand Name from name

# %%
df_lappy['Brand'] = np.nan
for i in range(df_lappy.shape[0]):
    df_lappy['Brand'][i] = df_lappy['name'][i].split()[0]
    
df_lappy.head()
# Out:
# D:\Data Science\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# D:\Data Science\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
#                                                 name  ratings  \
# 0  Lenovo Ideapad S145 Core i5 10th Gen - (8 GB/1...      4.0
# 1  Lenovo Ideapad S145 Core i3 10th Gen - (4 GB/1...      4.3
# 2  Acer Aspire 7 Core i5 9th Gen - (8 GB/512 GB S...      4.5
# 3  Apple MacBook Air Core i5 5th Gen - (8 GB/128 ...      4.7
# 4  Lenovo Ideapad L340 Core i5 9th Gen - (8 GB/1 ...      4.8
#
#                       num_ratings                           processor  \
# 0        431 Ratings & 62 Reviews  Intel Core i5 Processor (10th Gen)
# 1          20 Ratings & 4 Reviews  Intel Core i3 Processor (10th Gen)
# 2     5,317 Ratings & 979 Reviews   Intel Core i5 Processor (9th Gen)
# 3  25,629 Ratings & 2,870 Reviews   Intel Core i5 Processor (5th Gen)
# 4          56 Ratings & 6 Reviews   Intel Core i5 Processor (9th Gen)
#
#              ram                                  os              storage  \
# 0  8 GB DDR4 RAM  64 bit Windows 10 Operating System             1 TB HDD
# 1  4 GB DDR4 RAM  64 bit Windows 10 Operating System             1 TB HDD
# 2  8 GB DDR4 RAM  64 bit Windows 10 Operating System           512 GB SSD
# 3  8 GB DDR3 RAM      64 bit Mac OS Operating System           128 GB SSD
# 4  8 GB DDR4 RAM  64 bit Windows 10 Operating System  1 TB HDD|256 GB SSD
#
#                         display    price org_price   Brand
# 0  39.62 cm (15.6 inch) Display  ₹42,990   ₹66,190  Lenovo
# 1  39.62 cm (15.6 inch) Display  ₹31,990   ₹42,490  Lenovo
# 2  39.62 cm (15.6 inch) Display  ₹49,990   ₹79,999    Acer
# 3  33.78 cm (13.3 inch) Display  ₹59,990   ₹84,900   Apple
# 4  39.62 cm (15.6 inch) Display  ₹55,990   ₹79,690  Lenovo

# %% [markdown]
# ### Look for missing Values

# %%
df_lappy.isnull().sum()
# Out:
# name             0
# ratings        168
# num_ratings    168
# processor        0
# ram              0
# os               0
# storage         36
# display          0
# price            0
# org_price      106
# Brand            0
# dtype: int64

# %% [markdown]
# ### Separate Ratings and No. of Reviews

# %%
df_lappy.num_ratings[0]
# Out:
# '431 Ratings\xa0&\xa062 Reviews'

# %%
df_lappy.num_ratings[0].replace('\xa0','').split('&')
# Out:
# ['431 Ratings', '62 Reviews']

# %%
df_lappy['num_reviews'] = np.nan
for i in range(df_lappy.shape[0]):
    if(not pd.isnull(df_lappy['num_ratings'][i])):
        rr = df_lappy['num_ratings'][i].replace('\xa0','').split('&')
        rat_temp = rr[0].split()[0]
        rev_temp = rr[1].split()[0]

        if (',' in rat_temp):
            df_lappy['num_ratings'][i] = int(rr[0].split()[0].replace(',',''))
        else:
            df_lappy['num_ratings'][i] = int(rr[0].split()[0])

        if (',' in rev_temp):
            df_lappy['num_reviews'][i] = int(rr[1].split()[0].replace(',',''))
        else:
            df_lappy['num_reviews'][i] = int(rr[1].split()[0])
    
        

df_lappy.head()
# Out:
# D:\Data Science\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# D:\Data Science\lib\site-packages\ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# D:\Data Science\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# D:\Data Science\lib\site-packages\ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                                 name  ratings num_ratings  \
# 0  Lenovo Ideapad S145 Core i5 10th Gen - (8 GB/1...      4.0         431
# 1  Lenovo Ideapad S145 Core i3 10th Gen - (4 GB/1...      4.3          20
# 2  Acer Aspire 7 Core i5 9th Gen - (8 GB/512 GB S...      4.5        5317
# 3  Apple MacBook Air Core i5 5th Gen - (8 GB/128 ...      4.7       25629
# 4  Lenovo Ideapad L340 Core i5 9th Gen - (8 GB/1 ...      4.8          56
#
#                             processor            ram  \
# 0  Intel Core i5 Processor (10th Gen)  8 GB DDR4 RAM
# 1  Intel Core i3 Processor (10th Gen)  4 GB DDR4 RAM
# 2   Intel Core i5 Processor (9th Gen)  8 GB DDR4 RAM
# 3   Intel Core i5 Processor (5th Gen)  8 GB DDR3 RAM
# 4   Intel Core i5 Processor (9th Gen)  8 GB DDR4 RAM
#
#                                    os              storage  \
# 0  64 bit Windows 10 Operating System             1 TB HDD
# 1  64 bit Windows 10 Operating System             1 TB HDD
# 2  64 bit Windows 10 Operating System           512 GB SSD
# 3      64 bit Mac OS Operating System           128 GB SSD
# 4  64 bit Windows 10 Operating System  1 TB HDD|256 GB SSD
#
#                         display    price org_price   Brand  num_reviews
# 0  39.62 cm (15.6 inch) Display  ₹42,990   ₹66,190  Lenovo         62.0
# 1  39.62 cm (15.6 inch) Display  ₹31,990   ₹42,490  Lenovo          4.0
# 2  39.62 cm (15.6 inch) Display  ₹49,990   ₹79,999    Acer        979.0
# 3  33.78 cm (13.3 inch) Display  ₹59,990   ₹84,900   Apple       2870.0
# 4  39.62 cm (15.6 inch) Display  ₹55,990   ₹79,690  Lenovo          6.0

# %%
df_lappy.dtypes
# Out:
# name            object
# ratings        float64
# num_ratings     object
# processor       object
# ram             object
# os              object
# storage         object
# display         object
# price           object
# org_price       object
# Brand           object
# num_reviews    float64
# dtype: object

# %%
df_lappy['num_ratings'] = pd.to_numeric(df_lappy['num_ratings'] , errors = 'coerce')

# %%
df_lappy.dtypes
# Out:
# name            object
# ratings        float64
# num_ratings    float64
# processor       object
# ram             object
# os              object
# storage         object
# display         object
# price           object
# org_price       object
# Brand           object
# num_reviews    float64
# dtype: object

# %% [markdown]
# ### Clean RAM Variable and extract ram size and ram type

# %%
df_lappy['ram'][0].split()
# Out:
# ['8', 'GB', 'DDR4', 'RAM']

# %%
df_lappy['ram_type'] = np.nan
for i in range(df_lappy.shape[0]):
    ram_split = df_lappy['ram'][i].split()
    df_lappy['ram'][i] = ram_split[0]
    df_lappy['ram_type'][i] = ram_split[2]
# Out:
# D:\Data Science\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# D:\Data Science\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# D:\Data Science\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df_lappy.head()
# Out:
#                                                 name  ratings  num_ratings  \
# 0  Lenovo Ideapad S145 Core i5 10th Gen - (8 GB/1...      4.0        431.0
# 1  Lenovo Ideapad S145 Core i3 10th Gen - (4 GB/1...      4.3         20.0
# 2  Acer Aspire 7 Core i5 9th Gen - (8 GB/512 GB S...      4.5       5317.0
# 3  Apple MacBook Air Core i5 5th Gen - (8 GB/128 ...      4.7      25629.0
# 4  Lenovo Ideapad L340 Core i5 9th Gen - (8 GB/1 ...      4.8         56.0
#
#                             processor ram                                  os  \
# 0  Intel Core i5 Processor (10th Gen)   8  64 bit Windows 10 Operating System
# 1  Intel Core i3 Processor (10th Gen)   4  64 bit Windows 10 Operating System
# 2   Intel Core i5 Processor (9th Gen)   8  64 bit Windows 10 Operating System
# 3   Intel Core i5 Processor (5th Gen)   8      64 bit Mac OS Operating System
# 4   Intel Core i5 Processor (9th Gen)   8  64 bit Windows 10 Operating System
#
#                storage                       display    price org_price  \
# 0             1 TB HDD  39.62 cm (15.6 inch) Display  ₹42,990   ₹66,190
# 1             1 TB HDD  39.62 cm (15.6 inch) Display  ₹31,990   ₹42,490
# 2           512 GB SSD  39.62 cm (15.6 inch) Display  ₹49,990   ₹79,999
# 3           128 GB SSD  33.78 cm (13.3 inch) Display  ₹59,990   ₹84,900
# 4  1 TB HDD|256 GB SSD  39.62 cm (15.6 inch) Display  ₹55,990   ₹79,690
#
#     Brand  num_reviews ram_type
# 0  Lenovo         62.0     DDR4
# 1  Lenovo          4.0     DDR4
# 2    Acer        979.0     DDR4
# 3   Apple       2870.0     DDR3
# 4  Lenovo          6.0     DDR4

# %% [markdown]
# ### Clean Price Column

# %%
for i in range(df_lappy.shape[0]):
    df_lappy['price'][i] = df_lappy['price'][i].replace('₹','').replace(',','')
    
df_lappy.head()
# Out:
# D:\Data Science\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                                 name  ratings  num_ratings  \
# 0  Lenovo Ideapad S145 Core i5 10th Gen - (8 GB/1...      4.0        431.0
# 1  Lenovo Ideapad S145 Core i3 10th Gen - (4 GB/1...      4.3         20.0
# 2  Acer Aspire 7 Core i5 9th Gen - (8 GB/512 GB S...      4.5       5317.0
# 3  Apple MacBook Air Core i5 5th Gen - (8 GB/128 ...      4.7      25629.0
# 4  Lenovo Ideapad L340 Core i5 9th Gen - (8 GB/1 ...      4.8         56.0
#
#                             processor ram                                  os  \
# 0  Intel Core i5 Processor (10th Gen)   8  64 bit Windows 10 Operating System
# 1  Intel Core i3 Processor (10th Gen)   4  64 bit Windows 10 Operating System
# 2   Intel Core i5 Processor (9th Gen)   8  64 bit Windows 10 Operating System
# 3   Intel Core i5 Processor (5th Gen)   8      64 bit Mac OS Operating System
# 4   Intel Core i5 Processor (9th Gen)   8  64 bit Windows 10 Operating System
#
#                storage                       display  price org_price   Brand  \
# 0             1 TB HDD  39.62 cm (15.6 inch) Display  42990   ₹66,190  Lenovo
# 1             1 TB HDD  39.62 cm (15.6 inch) Display  31990   ₹42,490  Lenovo
# 2           512 GB SSD  39.62 cm (15.6 inch) Display  49990   ₹79,999    Acer
# 3           128 GB SSD  33.78 cm (13.3 inch) Display  59990   ₹84,900   Apple
# 4  1 TB HDD|256 GB SSD  39.62 cm (15.6 inch) Display  55990   ₹79,690  Lenovo
#
#    num_reviews ram_type
# 0         62.0     DDR4
# 1          4.0     DDR4
# 2        979.0     DDR4
# 3       2870.0     DDR3
# 4          6.0     DDR4

# %% [markdown]
# ### Clean Original Price Column

# %%
for i in range(df_lappy.shape[0]):
    if(not pd.isnull(df_lappy['org_price'][i])):
        df_lappy['org_price'][i] = df_lappy['org_price'][i].replace('₹','').replace(',','')
    else:
         df_lappy['org_price'][i] = df_lappy['org_price'][i]
    
df_lappy.head()
# Out:
# D:\Data Science\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# D:\Data Science\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
#                                                 name  ratings  num_ratings  \
# 0  Lenovo Ideapad S145 Core i5 10th Gen - (8 GB/1...      4.0        431.0
# 1  Lenovo Ideapad S145 Core i3 10th Gen - (4 GB/1...      4.3         20.0
# 2  Acer Aspire 7 Core i5 9th Gen - (8 GB/512 GB S...      4.5       5317.0
# 3  Apple MacBook Air Core i5 5th Gen - (8 GB/128 ...      4.7      25629.0
# 4  Lenovo Ideapad L340 Core i5 9th Gen - (8 GB/1 ...      4.8         56.0
#
#                             processor ram                                  os  \
# 0  Intel Core i5 Processor (10th Gen)   8  64 bit Windows 10 Operating System
# 1  Intel Core i3 Processor (10th Gen)   4  64 bit Windows 10 Operating System
# 2   Intel Core i5 Processor (9th Gen)   8  64 bit Windows 10 Operating System
# 3   Intel Core i5 Processor (5th Gen)   8      64 bit Mac OS Operating System
# 4   Intel Core i5 Processor (9th Gen)   8  64 bit Windows 10 Operating System
#
#                storage                       display  price org_price   Brand  \
# 0             1 TB HDD  39.62 cm (15.6 inch) Display  42990     66190  Lenovo
# 1             1 TB HDD  39.62 cm (15.6 inch) Display  31990     42490  Lenovo
# 2           512 GB SSD  39.62 cm (15.6 inch) Display  49990     79999    Acer
# 3           128 GB SSD  33.78 cm (13.3 inch) Display  59990     84900   Apple
# 4  1 TB HDD|256 GB SSD  39.62 cm (15.6 inch) Display  55990     79690  Lenovo
#
#    num_reviews ram_type
# 0         62.0     DDR4
# 1          4.0     DDR4
# 2        979.0     DDR4
# 3       2870.0     DDR3
# 4          6.0     DDR4

# %% [markdown]
# ### Clean The column Display

# %%
for i in range(df_lappy.shape[0]):
    df_lappy['display'][i] = df_lappy['display'][i].split()[0]
    
df_lappy.head()
# Out:
# D:\Data Science\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                                 name  ratings  num_ratings  \
# 0  Lenovo Ideapad S145 Core i5 10th Gen - (8 GB/1...      4.0        431.0
# 1  Lenovo Ideapad S145 Core i3 10th Gen - (4 GB/1...      4.3         20.0
# 2  Acer Aspire 7 Core i5 9th Gen - (8 GB/512 GB S...      4.5       5317.0
# 3  Apple MacBook Air Core i5 5th Gen - (8 GB/128 ...      4.7      25629.0
# 4  Lenovo Ideapad L340 Core i5 9th Gen - (8 GB/1 ...      4.8         56.0
#
#                             processor ram                                  os  \
# 0  Intel Core i5 Processor (10th Gen)   8  64 bit Windows 10 Operating System
# 1  Intel Core i3 Processor (10th Gen)   4  64 bit Windows 10 Operating System
# 2   Intel Core i5 Processor (9th Gen)   8  64 bit Windows 10 Operating System
# 3   Intel Core i5 Processor (5th Gen)   8      64 bit Mac OS Operating System
# 4   Intel Core i5 Processor (9th Gen)   8  64 bit Windows 10 Operating System
#
#                storage display  price org_price   Brand  num_reviews ram_type
# 0             1 TB HDD   39.62  42990     66190  Lenovo         62.0     DDR4
# 1             1 TB HDD   39.62  31990     42490  Lenovo          4.0     DDR4
# 2           512 GB SSD   39.62  49990     79999    Acer        979.0     DDR4
# 3           128 GB SSD   33.78  59990     84900   Apple       2870.0     DDR3
# 4  1 TB HDD|256 GB SSD   39.62  55990     79690  Lenovo          6.0     DDR4

# %% [markdown]
# ### Convert Price, org_price, ram and num_ratings to numeric

# %%
df_lappy['price'] = pd.to_numeric(df_lappy['price'] , errors = 'coerce')
df_lappy['org_price'] = pd.to_numeric(df_lappy['org_price'] , errors = 'coerce')
df_lappy['ram'] = pd.to_numeric(df_lappy['ram'] , errors = 'coerce')
df_lappy['display'] = pd.to_numeric(df_lappy['display'] , errors = 'coerce')

# %%
df_lappy.dtypes
# Out:
# name            object
# ratings        float64
# num_ratings    float64
# processor       object
# ram              int64
# os              object
# storage         object
# display        float64
# price            int64
# org_price      float64
# Brand           object
# num_reviews    float64
# ram_type        object
# dtype: object

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# ### Create a new column Discount

# %%
df_lappy['Discount'] = np.nan
for i in range(df_lappy.shape[0]):
    df_lappy['Discount'][i] = ((df_lappy['org_price'][i] -  df_lappy['price'][i])/ df_lappy['org_price'][i])*100
    
df_lappy.head()
# Out:
# D:\Data Science\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#                                                 name  ratings  num_ratings  \
# 0  Lenovo Ideapad S145 Core i5 10th Gen - (8 GB/1...      4.0        431.0
# 1  Lenovo Ideapad S145 Core i3 10th Gen - (4 GB/1...      4.3         20.0
# 2  Acer Aspire 7 Core i5 9th Gen - (8 GB/512 GB S...      4.5       5317.0
# 3  Apple MacBook Air Core i5 5th Gen - (8 GB/128 ...      4.7      25629.0
# 4  Lenovo Ideapad L340 Core i5 9th Gen - (8 GB/1 ...      4.8         56.0
#
#                             processor  ram  \
# 0  Intel Core i5 Processor (10th Gen)    8
# 1  Intel Core i3 Processor (10th Gen)    4
# 2   Intel Core i5 Processor (9th Gen)    8
# 3   Intel Core i5 Processor (5th Gen)    8
# 4   Intel Core i5 Processor (9th Gen)    8
#
#                                    os              storage  display  price  \
# 0  64 bit Windows 10 Operating System             1 TB HDD    39.62  42990
# 1  64 bit Windows 10 Operating System             1 TB HDD    39.62  31990
# 2  64 bit Windows 10 Operating System           512 GB SSD    39.62  49990
# 3      64 bit Mac OS Operating System           128 GB SSD    33.78  59990
# 4  64 bit Windows 10 Operating System  1 TB HDD|256 GB SSD    39.62  55990
#
#    org_price   Brand  num_reviews ram_type   Discount
# 0    66190.0  Lenovo         62.0     DDR4  35.050612
# 1    42490.0  Lenovo          4.0     DDR4  24.711697
# 2    79999.0    Acer        979.0     DDR4  37.511719
# 3    84900.0   Apple       2870.0     DDR3  29.340400
# 4    79690.0  Lenovo          6.0     DDR4  29.740243

# %%
df_lappy.to_csv('lappy_eda.csv', index=False)

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Read the CSV File

# %%
df_lappy = pd.read_csv('lappy_eda.csv')
df_lappy
# Out:
#                                                   name  ratings  num_ratings  \
# 0    Lenovo Ideapad S145 Core i5 10th Gen - (8 GB/1...      4.0        431.0
# 1    Lenovo Ideapad S145 Core i3 10th Gen - (4 GB/1...      4.3         20.0
# 2    Acer Aspire 7 Core i5 9th Gen - (8 GB/512 GB S...      4.5       5317.0
# 3    Apple MacBook Air Core i5 5th Gen - (8 GB/128 ...      4.7      25629.0
# 4    Lenovo Ideapad L340 Core i5 9th Gen - (8 GB/1 ...      4.8         56.0
# ..                                                 ...      ...          ...
# 571  HP 15 Core i3 8th Gen - (4 GB/1 TB HDD/Windows...      4.0        407.0
# 572  Asus ZenBook 13 Core i5 8th Gen - (8 GB/512 GB...      4.5        290.0
# 573  Lenovo Ideapad L340 Core i5 9th Gen - (8 GB/1 ...      4.3        201.0
# 574  Asus Athlon Dual Core 3050U - (4 GB/1 TB HDD/W...      NaN          NaN
# 575  HP 15s Core i5 10th Gen - (4 GB/1 TB HDD/256 G...      4.3        138.0
#
# ...

# %% [markdown]
# Numerical vs. Numerical
# 1. Scatterplot
# 2. Line plot
# 3. Heatmap for correlation
# 4. Joint plot
#
# Categorical vs. Numerical
# 1. Bar chart
# 2. Violin plot
# 3. Categorical box plot
# 4. Swarm plot
#
# Two Categorical Variables
# 1. Bar chart
# 2. Grouped bar chart
# 3. Point plot

# %%
df_lappy.tail()
# Out:
#                                                   name  ratings  num_ratings  \
# 571  HP 15 Core i3 8th Gen - (4 GB/1 TB HDD/Windows...      4.0        407.0
# 572  Asus ZenBook 13 Core i5 8th Gen - (8 GB/512 GB...      4.5        290.0
# 573  Lenovo Ideapad L340 Core i5 9th Gen - (8 GB/1 ...      4.3        201.0
# 574  Asus Athlon Dual Core 3050U - (4 GB/1 TB HDD/W...      NaN          NaN
# 575  HP 15s Core i5 10th Gen - (4 GB/1 TB HDD/256 G...      4.3        138.0
#
#                               processor  ram  \
# 571   Intel Core i3 Processor (8th Gen)    4
# 572   Intel Core i5 Processor (8th Gen)    8
# 573   Intel Core i5 Processor (9th Gen)    8
# 574      AMD Athlon Dual Core Processor    4
# 575  Intel Core i5 Processor (10th Gen)    4
#
#                                      os              storage  display  price  \
# 571  64 bit Windows 10 Operating System             1 TB HDD    39.62  40490
# ...

# %%
df_lappy.shape
# Out:
# (576, 14)

# %%
df_lappy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 576 entries, 0 to 575
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         576 non-null    object
#  1   ratings      408 non-null    float64
#  2   num_ratings  408 non-null    float64
#  3   processor    576 non-null    object
#  4   ram          576 non-null    int64
#  5   os           576 non-null    object
#  6   storage      540 non-null    object
#  7   display      565 non-null    float64
#  8   price        576 non-null    int64
#  9   org_price    470 non-null    float64
#  10  Brand        576 non-null    object
#  11  num_reviews  408 non-null    float64
#  12  ram_type     576 non-null    object
#  13  Discount     470 non-null    float64
# dtypes: float64(6), int64(2), object(6)
# memory usage: 63.1+ KB

# %%
df_lappy.describe(include='all')
# Out:
#                                                      name     ratings  \
# count                                                 576  408.000000
# unique                                                439         NaN
# top     Lenovo Ideapad S145 Core i5 10th Gen - (8 GB/1...         NaN
# freq                                                   26         NaN
# mean                                                  NaN    4.219363
# std                                                   NaN    0.469139
# min                                                   NaN    1.600000
# 25%                                                   NaN    4.000000
# 50%                                                   NaN    4.300000
# 75%                                                   NaN    4.500000
# max                                                   NaN    5.000000
#
#          num_ratings                           processor         ram  \
# ...

# %%
df_lappy.isnull().sum().sum()
# Out:
# 763

# %%
df_lappy.corr()
# Out:
#               ratings  num_ratings       ram   display     price  org_price  \
# ratings      1.000000     0.014322  0.349844  0.103899  0.321364   0.458364
# num_ratings  0.014322     1.000000 -0.085634 -0.098281 -0.100210  -0.084290
# ram          0.349844    -0.085634  1.000000  0.282854  0.829959   0.848139
# display      0.103899    -0.098281  0.282854  1.000000  0.197468   0.228170
# price        0.321364    -0.100210  0.829959  0.197468  1.000000   0.980088
# org_price    0.458364    -0.084290  0.848139  0.228170  0.980088   1.000000
# num_reviews  0.014494     0.984182 -0.089883 -0.099047 -0.104625  -0.102523
# Discount     0.198609     0.033894 -0.045225  0.184993 -0.181947  -0.012054
#
#              num_reviews  Discount
# ratings         0.014494  0.198609
# num_ratings     0.984182  0.033894
# ram            -0.089883 -0.045225
# display        -0.099047  0.184993
# price          -0.104625 -0.181947
# org_price      -0.102523 -0.012054
# ...

# %%
sns.boxplot(df_lappy.price)

# %%
sns.boxplot(df_lappy.ratings)

# %%
sns.boxplot(df_lappy.Discount)

# %%
df_lappy.Brand.value_counts().plot(kind = 'bar' , figsize = (15,8))

# %%
corrmat = df_lappy.corr()

# %%
plt.figure(figsize = (15,8))
sns.heatmap(corrmat, cmap='BrBG', annot=True)

# %%
sns.scatterplot(df_lappy.price , df_lappy.ram)

# %%
sns.scatterplot(df_lappy.price , df_lappy.Discount)

# %%
sns.scatterplot(df_lappy.price , df_lappy.display)

# %% [markdown]
# ### Sort the dataframe on the basis of price

# %%
df_lappy = df_lappy.sort_values('price' , ascending=False)
df_lappy.head(10)
# Out:
#                                                   name  ratings  num_ratings  \
# 201  Alienware Core i9 10th Gen - (32 GB/1 TB SSD/W...      4.8          5.0
# 264  Asus ROG Zephyrus Duo 15 Core i7 10th Gen - (3...      NaN          NaN
# 275  Asus ROG Zephyrus S Core i7 9th Gen - (24 GB/1...      NaN          NaN
# 185  Asus ROG Zephyrus S17 Core i7 10th Gen - (32 G...      NaN          NaN
# 267  Asus ROG Zephyrus Duo 15 Core i7 10th Gen - (3...      NaN          NaN
# 280  Asus ROG Zephyrus S15 Core i7 10th Gen - (32 G...      NaN          NaN
# 227  Asus ROG Strix Scar 17 Core i9 10th Gen - (32 ...      NaN          NaN
# 301  Asus Core i9 10th Gen - (32 GB/1 TB SSD/Window...      NaN          NaN
# 210  MSI GS75 Stealth Core i9 10th Gen - (32 GB/1 T...      NaN          NaN
# 211  MSI GS66 Stealth Core i7 10th Gen - (32 GB/1 T...      NaN          NaN
#
#                               processor  ram  \
# 201  Intel Core i9 Processor (10th Gen)   32
# ...

# %% [markdown]
# ### Take non null rows based on ratings and store the result in a new dataframe

# %%
max(df_lappy['ratings'])
# Out:
# 5.0

# %%
df_temp = df_lappy[pd.notnull(df_lappy['ratings'])]
df_temp
# Out:
#                                                   name  ratings  num_ratings  \
# 201  Alienware Core i9 10th Gen - (32 GB/1 TB SSD/W...      4.8          5.0
# 248  Apple Macbook Pro Core i7 8th Gen - (16 GB/512...      4.0         10.0
# 274  Asus ZenBook Pro 15 Core i9 8th Gen - (16 GB/1...      5.0          3.0
# 207  Apple MacBook Pro Core i9 8th Gen - (16 GB/512...      4.2         16.0
# 186  Alienware Core i7 10th Gen - (16 GB/512 GB SSD...      4.9          8.0
# ..                                                 ...      ...          ...
# 322  LifeDigital Zed Celeron Dual Core - (4 GB/128 ...      3.6        154.0
# 395  iBall CompBook Pentium Quad Core - (4 GB/32 GB...      3.8       1174.0
# 542  Lava Helium 12 Atom 7th Gen - (2 GB/32 GB HDD/...      4.0         12.0
# 218  Avita Magus Lite Celeron Dual Core - (4 GB/64 ...      3.8        444.0
# 167  Avita Magus Lite Celeron Dual Core - (4 GB/64 ...      3.8        444.0
#
# ...

# %% [markdown]
# ### Highest Discount

# %%
df_lappy[df_lappy['Discount'] == max(df_lappy['Discount'])]
# Out:
#                                                   name  ratings  num_ratings  \
# 326  Avita Pura Core i3 8th Gen - (4 GB/256 GB SSD/...      NaN          NaN
# 315  Avita Pura Core i3 8th Gen - (4 GB/256 GB SSD/...      NaN          NaN
# 294  Avita Pura Core i3 8th Gen - (4 GB/256 GB SSD/...      NaN          NaN
#
#                              processor  ram  \
# 326  Intel Core i3 Processor (8th Gen)    4
# 315  Intel Core i3 Processor (8th Gen)    4
# 294  Intel Core i3 Processor (8th Gen)    4
#
#                                      os     storage  display  price  \
# 326  64 bit Windows 10 Operating System  256 GB SSD    35.56  28990
# 315  64 bit Windows 10 Operating System  256 GB SSD    35.56  28990
# 294  64 bit Windows 10 Operating System  256 GB SSD    35.56  28990
#
#      org_price  Brand  num_reviews ram_type   Discount
# 326    69844.0  Avita          NaN     DDR3  58.493213
# 315    69844.0  Avita          NaN     DDR3  58.493213
# ...

# %% [markdown]
# ### Highest number of ratings

# %%
df_lappy[df_lappy['num_ratings'] == max(df_lappy['num_ratings'])]
# Out:
#                                                 name  ratings  num_ratings  \
# 3  Apple MacBook Air Core i5 5th Gen - (8 GB/128 ...      4.7      25629.0
#
#                            processor  ram                              os  \
# 3  Intel Core i5 Processor (5th Gen)    8  64 bit Mac OS Operating System
#
#       storage  display  price  org_price  Brand  num_reviews ram_type  \
# 3  128 GB SSD    33.78  59990    84900.0  Apple       2870.0     DDR3
#
#    Discount
# 3   29.3404
